# %%
from trading import *

# %matplotlib inline

# %%
NIFTY = YTicker("^NSEI")
NIFTY.print_info()
# Out:
# {'averageDailyVolume10Day': 486130,
#  'averageVolume': 355166,
#  'averageVolume10days': 486130,
#  'currency': 'INR',
#  'dayHigh': 23320.2,
#  'dayLow': 22789.05,
#  'exchange': 'NSI',
#  'fiftyDayAverage': 22469.49,
#  'fiftyTwoWeekHigh': 23338.7,
#  'fiftyTwoWeekLow': 18559.75,
#  'firstTradeDateEpochUtc': 1190000700,
#  'gmtOffSetMilliseconds': 19800000,
#  'longName': 'NIFTY 50',
#  'maxAge': 86400,
#  'messageBoardId': 'finmb_INDEXNSEI',
#  'open': 22821.85,
#  'previousClose': 22821.4,
#  'priceHint': 2,
#  'quoteType': 'INDEX',
#  'regularMarketDayHigh': 23320.2,
#  'regularMarketDayLow': 22789.05,
#  'regularMarketOpen': 22821.85,
#  'regularMarketPreviousClose': 22821.4,
#  'shortName': 'NIFTY 50',
#  'symbol': '^NSEI',
#  'timeZoneFullName': 'Asia/Kolkata',
#  'timeZoneShortName': 'IST',
#  'trailingPegRatio': None,
#  'twoHundredDayAverage': 21105.982,
#  'underlyingSymbol': '^NSEI',
#  'uuid': '9a3680d6-8f20-3f84-8cd3-66d847143a00'}

# %%
plot = plotting.CandlestickPlot(NIFTY)

plot.indicator(BollingerBands())
plot.indicator(SMAIndicator(window=20))

plot.show(period=periods.ytd, interval=intervals.day)
