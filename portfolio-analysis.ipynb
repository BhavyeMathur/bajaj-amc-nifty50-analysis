# %%
from trading import *

# %matplotlib inline

# %%
zomato = YTicker("ZOMATO.NS")
bel = YTicker("BEL.NS")
irfc = YTicker("IRFC.NS")
ntpc = YTicker("NTPC.NS")
rpower = YTicker("RPOWER.NS")
tatamotors = YTicker("TATAMOTORS.NS")
reliance = YTicker("RELIANCE.NS")
avanti = YTicker("AVANTIFEED.NS")
rec = YTicker("RECLTD.NS")
asian = YTicker("ASIANPAINT.NS")
lici = YTicker("LICI.NS")
bhel = YTicker("BHEL.NS")


bhavye = Portfolio(zomato, bel, irfc, ntpc, rpower, bhel)
bhavye.weights = [4081, 4520, 3589, 4398, 1619, 3925]

mohit = Portfolio(tatamotors, reliance, avanti, rec, asian, lici)
mohit.weights = [190.26, 215.42, 121.455, 167.37, 142.59, 128.99]

# %%
model = capm.EfficientFrontier(mohit, period="max")
model.plot(10000)
model.plot_position()
model.show()
